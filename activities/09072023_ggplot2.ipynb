# %%
library("tidyverse")

# %%
options(repr.plot.width=4, repr.plot.height=3, repr.plot.res = 300)

# %%
library("palmerpenguins")

# %%
penguins %>% head
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %%
p = ggplot(penguins, aes(y = species, fill = sex)) +
    geom_bar(position = 'dodge')
p

# 'dodge' makes different columns. without it, data is stacked in one column
# geom_bar only expects y to be set
# fill refers to how to color the bars
# Out:
# plot without title

# %%
df_counts = penguins %>%
    drop_na() %>%
    group_by(species, sex) %>%
    count()

df_counts
# Out:
#   species   sex    n
# 1 Adelie    female 73
# 2 Adelie    male   73
# 3 Chinstrap female 34
# 4 Chinstrap male   34
# 5 Gentoo    female 58
# 6 Gentoo    male   61

# %% [markdown]
# We want to visualize the number of each sex within each species?
#
# - What kind of plot? (bars?, points? other?)
# - What are the axes?
# - What other encodings could we try?

# %% [markdown]
# <img src="count_sex_by_species.png" style="width: 600px;" />

# %% [markdown]
# We want to visualize the number of each sex within each species?
#
# - What kind of plot? Bar chart
#   - determines the "geom"
# - What are the axes? X is "species" Y is "n" (or the count)
#   - this goes in the "aes" function
# - What other encodings could we try? color/group by "sex"
#   - this also goes in the "aes" function

# %%
p = ggplot(df_counts, aes(x = species, y = n, fill = sex))

p = p + geom_col()

p
# Out:
# plot without title

# %%
p = ggplot(df_counts, aes(x = species, y = n, fill = sex))

p = p + geom_col(position = "dodge")

p

# geom_col expects x and y to be set
# Out:
# plot without title

# %%
options(repr.plot.width = 5, repr.plot.height = 3, repr.plot.res = 300) 

p = ggplot(df_counts, aes(x = species, y = n))

p = p + geom_col()

p = p + facet_wrap(~sex)

p
# Out:
# plot without title

# %%
options(repr.plot.width = 7)

p = ggplot(penguins |> drop_na(), aes(y = species, fill = sex)) +
    geom_bar() +
    facet_wrap(~sex, ncol = 2)
p

# facet_wrap splits into multiple charts
# Out:
# plot without title
