# %% [markdown]
# # Multiple plots

# %% [markdown]
# ## Review from last lecture...

# %%
library('tidyverse')

# This will make your plots look better in Jupyter
options(repr.plot.width = 4, repr.plot.height = 3, repr.plot.res = 300)
# Out:
# Warning message:
# “Failed to locate timezone database”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
p = ggplot(mpg, aes(x = displ, y = hwy)) 

p = p + geom_point()

p
# Out:
# plot without title

# %%
# alternatively add data and mapping in the geom. these are named arguments

p = ggplot() +
    geom_point(data = mpg, mapping = aes(x = displ, y = hwy))

p
# Out:
# plot without title

# %%
# How to change the color of all the points (i.e. not map them to a column in the data)?

p = ggplot(mpg, aes(x = displ, y = hwy))

p = p + geom_point(color = 'firebrick', alpha = 0.5)

p

# alpha makes points transparent. more transparent the lower the alpha value
# darker points means there are multiple data points there
# Out:
# plot without title

# %%
p = ggplot(mpg, aes(x = displ, y = hwy, alpha = displ))

p = p + geom_point(color = 'firebrick')

p
# Out:
# plot without title

# %%
# What other chart properties can be "mapped?"
# X, Y, color...
# Hint: # https://r4ds.had.co.nz/data-visualisation.html#fig:shapes

p = ggplot(mpg, aes(x = cty, y = hwy))

p = p + geom_point(shape = 22, fill = 'pink', color = 'black')

p

# for square points, shape = 22
# more shape values, https://r4ds.had.co.nz/data-visualisation.html#fig:shapes
# Out:
# plot without title

# %% [markdown]
# # Facets

# %% [markdown]
# ## facet_wrap

# %%
# Let's use a different data set

iris |> head()
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
p = ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, color = Species))

p = p + geom_point() 

p = p + scale_color_brewer(type = "qual", palette = "Set2")

p
# Out:
# plot without title

# %%
options(repr.plot.width = 8, repr.plot.height = 6)

p = ggplot(iris, aes(x = Sepal.Length, 
                     y = Sepal.Width, 
                     color = Species))

p = p + geom_point() 

p = p + scale_color_brewer(type = "qual", 
                           palette = "Set2")

p = p + facet_wrap(~Species, nrow = 2)

p

# facet_wrap creates multiple plots
# facet_wrap(~[column name], nrow = [# of rows])
# can also do ncol instead of nrow
# Out:
# plot without title

# %%
options(repr.plot.width=4, repr.plot.height=6)

p = p + facet_wrap(~Species, ncol = 1)

p
# Out:
# plot without title

# %% [markdown]
# ## facet_grid

# %%
mpg %>% head
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
mpg %>% group_by(drv) %>% tally() %>% arrange(desc(n))
# Out:
#   drv n
# 1 f   106
# 2 4   103
# 3 r    25

# %%
mpg %>% group_by(cyl) %>% tally() %>% arrange(desc(n))
# Out:
#   cyl n
# 1 4   81
# 2 6   79
# 3 8   70
# 4 5    4

# %%
options(repr.plot.width=10, repr.plot.height=8)

p = ggplot(mpg, aes(x = displ, y = hwy))

p = p + geom_point()

p = p + facet_grid(drv ~ cyl)

p = p + theme(strip.text = element_text(size = 20))

p
# Out:
# plot without title

# %% [markdown]
# # Additional packages
# E.g. [Patchwork](https://github.com/thomasp85/patchwork)

# %% [markdown]
# ## Workflow
#
# 1. research (i.e. "google")
# 1. install (we'll learn this later)
# 1. import (`library`)
# 1.  use

# %% [markdown]
# [patchwork](https://github.com/thomasp85/patchwork)

# %%
library('patchwork')
library('tidyverse')

# %%
options(repr.plot.width=4, repr.plot.height=3)

mpg.new = mpg %>% mutate(outlier = ifelse(hwy > 20 & displ > 5, 'yes', 'no')) 

p = ggplot(mpg.new, aes(x = displ, y = hwy, color = outlier))
    
p = p + geom_point()

p = p + scale_color_manual(values=c('black', 'red'))

p
# Out:
# plot without title

# %%
mpg.new %>% head
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class   outlier
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact no
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact no
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact no
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact no
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact no
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact no

# %%
p2 = ggplot(mpg, aes(x = displ, y = hwy, color = class))

p2 = p2 + geom_point()

p2
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=4)

p + p2
# Out:
# plot without title
